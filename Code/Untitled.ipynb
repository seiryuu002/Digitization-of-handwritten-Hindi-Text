# %%
# !pip install easyocr --user

# %%
import matplotlib.pyplot as plt
import cv2
import easyocr
from pylab import rcParams
from IPython.display import Image

# %%
rcParams['figure.figsize'] = 8, 16

# %%
reader = easyocr.Reader(['en', 'hi'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
file = Image.open("Handwriting1.jpeg")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-481260b88d22> in <module>
# ----> 1 file = Image.open("Handwriting1.jpeg")
#
# AttributeError: type object 'Image' has no attribute 'open'

# %%
Image(file)

# %%
Output = reader.readtext(file)

# %%
Output
# Out:
# [([[353, 3], [415, 3], [415, 41], [353, 41]], 'म', 0.9754105635370571),
#  ([[457, 1], [539, 1], [539, 45], [457, 45]], 'त', 0.9766445759116529),
#  ([[557, 5], [611, 5], [611, 41], [557, 41]], 'े', 0.06844893069690361),
#  ([[631, 1], [681, 1], [681, 43], [631, 43]], 'ल', 0.9998946217643265)]
